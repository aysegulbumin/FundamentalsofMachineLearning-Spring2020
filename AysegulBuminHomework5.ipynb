# %% [markdown]
# # Homework 5 - Neural Networks
#
# This is an individual assignment.
#
# **Due: Wednesday, April 15 @ 11:59 PM**
#
# ## Grading Rubric
#
# 1. **Problem 1 (50 pts):** you have completed all calculations and showed your work. You can upload a PDF scan of your handwritten calculations.
#
# 2. **Problem 2 (50 pts):** you have answered all questions and included the appropriate discussion.
#
# **Total: 100 pts**

# %% [markdown]
# # Multi-Layer Perceptrons and Backpropagation
#
# In this assignment, you will explore multi-layer perceptrons, backpropagation and parameter tuning. You have been given a data set that you will need for one of the problems (**UF_network.npy**) - make sure you download it.

# %% [markdown]
# # Problem 1 - Backpropagation
#
# Consider the following network: 1 input layer, 1 hidden layer and 1 output layer, each layer with 2 neurons.
#
# <div><img src="network.png", width="700"><!div>
#
# All weights are initialized to the values shown (and there are no biases for simplicity). Consider the data point $x=[1,1]^T$ with desired output vector $d=[1,0]^T$. Complete one iteration of backpropagation by hand assuming a learning rate of $\eta=0.1$.
#
# What would all the weight values be after one backpropagation iteration? Show your work.
#
# Use the sigmoid activation function: $\phi(x) = \frac{1}{1 + e^{-x}}$. Note that $\frac{d\phi(x)}{dx}=\phi'(x) = \phi(x)(1-\phi(x))$.

# %% [markdown]
# # Problem 2 - Learning Strategies
#
# In this problem, you will be working with the data set "UF Network" shown below (make sure you download the file **"UF_network.npy"**):

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.colors import ListedColormap

UF_network = np.load('UF_network.npy')
X = UF_network[:,:2]
y = UF_network[:,2]

cm = ListedColormap(['blue', 'orange'])
plt.scatter(X[:,0],X[:,1],c=y, cmap=cm);
plt.xlabel('Feature 1')
plt.ylabel('Feature 2');

# %% [markdown]
# The following function will be helpful for plotting the decision boundary of your trained model.

# %%
def plot_LC_and_DB(X, model):
    '''This function will plot the learning curve and decision boundary
    for a given trained model and training data X.
    model: is a sklearn model structure
    X: training data'''
    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.02),
                             np.arange(y_min, y_max, 0.02))
    
    fig = plt.figure(figsize=(15,5))
    fig.add_subplot(1,2,1)
    plt.plot(model.loss_curve_)
    plt.title('Learning Curve')
    plt.xlabel('Epochs')
    plt.ylabel('Loss Function')

    cm = ListedColormap(['blue', 'orange'])
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape) 
    fig.add_subplot(1,2,2)
    plt.contourf(xx, yy, Z, cmap=cm, alpha=.8);
    plt.title('Decision Boundary')
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.show();

# %% [markdown]
# For this problem, you will need to create a 2-hidden layer network to distinguish the letters and the background. Starter code is provided for you in the below code cell; it is using the ```scikit-learn``` library. You will need to determine:
#
# (1) the number of units for each hidden layer,
# (2) the learning rate, and
# (3) number of epochs.
#
# Answer the following questions:
#
# 1. How many units will you need in the first and second hidden layers? Why? Justify your answer by providing an explanation of each hidden unit role in creating the UF network.
#
# 2. Can you achieve the same goal with a *single hidden layer network*? Why or why not?
#
# 3. Using the starter code below, select three different learning rates and number of epochs. Report the results on the values selected. Generate the (a) learning curve and (b) decision boundary for the top three combinations of the different learning rates and number of epochs (total of 6 figures).
#
# 4. For the best learning rate and number epochs from the above plots, provide discussion on the (a) influence of each hyperparameter on training performance and (b) why the selected values worked well.

# %%
from sklearn.metrics import accuracy_score
from sklearn.neural_network import MLPClassifier

# Do not change these parameters
net = MLPClassifier(activation='tanh',
                    n_iter_no_change = 1000)

# %%
# Create a list with your own set of values for all of these parameters
#net_hidden_layers = [(16,7),(16,12),(17,7),(17,12),(18,7),(18,12)]#
net_hidden_layers = [(16,7),(17,7),(18,7)]#
net_learning_rate =[1,0.05,0.001]#
epochs =[50,100,200] #

for i in net_hidden_layers:
    for j in net_learning_rate:
        for k in epochs:
            net.set_params(hidden_layer_sizes = i, learning_rate_init = j, max_iter = k)
            net.fit(X, y)
            y_pred = net.predict(X)

            acc_score = accuracy_score(y, y_pred)
            print('-----------------------------------')
            print('Hidden Layer 1 Architecture: ', i[0])
            print('Hidden Layer 2 Architecture: ', i[1])
            print('Learning Rate: ', j)
            print('Number of Epochs: ', k)
            print('Accuracy = ', np.round(acc_score*100,2),'%')
            print('-----------------------------------')
            plot_LC_and_DB(X, net)
# Out:
# /home/aysegulbumin/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# -----------------------------------
# Hidden Layer 1 Architecture:  16
# Hidden Layer 2 Architecture:  7
# Learning Rate:  1
# Number of Epochs:  50
# Accuracy =  73.8 %
# -----------------------------------
# /home/aysegulbumin/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# -----------------------------------
# Hidden Layer 1 Architecture:  16
# Hidden Layer 2 Architecture:  7
# Learning Rate:  1
# Number of Epochs:  100
# Accuracy =  70.93 %
# -----------------------------------
# ...

# %% [markdown]
# ## Submit your Solution
#
# Create a PDF of the notebook with your solutions.
#
# Submit both your notebook and the PDF of your notebook to Homework 4 assignment page on Canvas.
#
# * For full credit consideration, make sure all output cells do not show any errors and all code is visible.

# %% [markdown]
# Answer the following questions:
#
#    * How many units will you need in the first and second hidden layers? Why? Justify your answer by providing an explanation of each hidden unit role in creating the UF network.
#
#     The first hidden layer is used to distinguish the two classes. By each neuron in the first hidden layer we define a particular line. The question then boils down to how many lines are needed to describe UF within the blue background. In UF example, in order to distinguish U we have right and left of the vertical arms of U,(4 lines) and 3-4 horizontal lines for top boundary, bottom boundary and the mid boundary. Can be thought as  ||_-|| + upper and lower horizontal lines. So 7-8 lines are needed. And in order to distinguish F, we need 5 horizontal lines for 2 for upper horizontal 2 for lower horizontal and one for bottom. Moreover we need 4-5 vertical lines depending on the linearity of the sections. So overall we will need 9-10 for F, 7-8 for U. 16-18 neurons in total.
#
#     Second hidden layer is to combine the information got from hidden layer, to a higher level. In the examples in the class we picked the number of neurons in the second layer to be the number of convex parts of our objective. Here as well we can think similarly I thought of 2 different cases. In the first one we can think of every small piece that the lines defined above separates, how many of such convex shapes would we have? According to my calculation for U we would have 5, for F we would have 7 such convex regions(12 in total). However we can think some of the convex shapes together,combined and with that approach there will be around 7 (convex shapes) neurons in total. I tried both and in my results I represent the one that I found to work better which is 7.
#
#    * Can you achieve the same goal with a single hidden layer network? Why or why not?
#
#     I believe we cannot achieve the same goal with a single hidden layer because there are two concepts that we are trying to combine, one of them is defining the regions of one particular class, which is handled by the first layer.The other one is combining these regions to a higher level shape. Which is the combination of the convex shapes.
#
#    * Using the starter code below, select three different learning rates and number of epochs. Report the results on the values selected. Generate the (a) learning curve and (b) decision boundary for the top three combinations of the different learning rates and number of epochs (total of 6 figures).
#
#     The results are presented in the plots above.
#
#    * For the best learning rate and number epochs from the above plots, provide discussion on the (a) influence of each hyperparameter on training performance and (b) why the selected values worked well.
#
#     In this homework we focus on two different hyper parameters one being the learning rate and the other being the number of epochs. As we discussed deeply in the class the learning rate plays an important role. As we increase the learning rate according to my observation the algorithm either behaves weirdly or keeps fluctuating between certain values we can see the fluctuation looking at the learning curve. On the other hand when we keep the learning rate small then the number of epochs to perform good is very high. We may not end up trying those epochs. I ran the algorithms with upto 200 epoch in the submission, as I tried some larger number for epoch like 200,300 when learning rate is 0.001 then the 100 epoch did not perform well however after 200 epoch the accuracy increased.
#     Another hyper parameter is the number of epochs. I kind of mentioned the effect of larger epoch when the learning rate is small. If the learning rate is small then increasing the number of epochs may result in huge increase in accuracy, of course still dependent on the learning rate chosen. And in some cases after certain number of epochs there is no further increase in accuracy, there we assume that the algorithm converged. Basically with a very small number of epochs we may not be able to see the actual performance of the algorithms.
#
#     The best epoch:100
#     The best learning rate: 0.05,
#     second best learning rate: 0.01
#
# Best Performance Observed
# -----------------------------------
# Hidden Layer 1 Architecture:  18
#
# Hidden Layer 2 Architecture:  7
#
# Learning Rate:  0.05
#
# Number of Epochs:  200
#
# Accuracy : 99.8 %
#
# P.S As I rerun the experiments the best accuracy changed between 99.0 to 99.8 but I wrote the best among all the trials that I have done, hence the best performance accuracy may not match with the result above. The best result can vary between Hidden Layer 16 to 18 as well
